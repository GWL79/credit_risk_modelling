# %%
import numpy as np
import pandas as pd

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col = 0, header = None)

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 104567      104567   6616752    8198895       9600         9600
# 19977        19977    666996     852743      18000        18000
# 208099      208099   1416681    1666699      10000        10000
# 206328      206328   1435772    1687345      30000        30000
# 377868      377868  16221339   18323829      22000        22000
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 104567           9550.0   36 months      8.90       304.84     A  ...
# 19977           18000.0   60 months     16.77       445.13     E  ...
# 208099          10000.0   36 months      8.90       317.54     A  ...
# 206328          30000.0   36 months     17.27      1073.62     C  ...
# 377868          22000.0   36 months      7.69       686.26     A  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 104567             0           0       0                              1
# 19977              0           1       0                              1
# 208099             0           0       0                              1
# 206328             0           0       0                              1
# 377868             0           0       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 104567                           0                           0
# 19977                            0                           0
# 208099                           0                           0
# 206328                           0                           0
# 377868                           0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 104567                            0                            0
# 19977                             0                            0
# 208099                            0                            0
# 206328                            0                            0
# 377868                            0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>=86
# 104567                            0                           0
# 19977                             0                           0
# 208099                            0                           0
# 206328                            0                           0
# 377868                            0                           0
#
# [5 rows x 324 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 104567         1
# 19977          0
# 208099         1
# 206328         1
# 377868         1

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 324)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 324)

# %%
loan_data_targets_test.shape
# Out:
# (93258, 1)

# %%
loan_data_inputs_train["home_ownership: rent_other_none_any"] = sum([loan_data_inputs_train["home_ownership:ANY"], loan_data_inputs_train["home_ownership:NONE"], loan_data_inputs_train["home_ownership:OTHER"], loan_data_inputs_train["home_ownership:RENT"]])

# %%
loan_data_inputs_test["home_ownership: rent_other_none_any"] = sum([loan_data_inputs_test["home_ownership:ANY"], loan_data_inputs_test["home_ownership:NONE"], loan_data_inputs_test["home_ownership:OTHER"], loan_data_inputs_test["home_ownership:RENT"]])

# %%
loan_data_inputs_train.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'member_id', 'loan_amnt', 'funded_amnt',
#        'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'last_pymnt_d',
#        'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'emp_length_int', 'earliest_cr_line_date',
#        'mths_since_earliest_cr_line', 'term_int', 'issue_d_date',
#        'mths_since_issue_d', 'grade:A', 'grade:B', 'grade:C', 'grade:D',
#        'grade:E', 'grade:F', 'grade:G', 'sub_grade:A1', 'sub_grade:A2',
#        'sub_grade:A3', 'sub_grade:A4', 'sub_grade:A5', 'sub_grade:B1',
#        'sub_grade:B2', 'sub_grade:B3', 'sub_grade:B4', 'sub_grade:B5',
#        'sub_grade:C1', 'sub_grade:C2', 'sub_grade:C3', 'sub_grade:C4',
#        'sub_grade:C5', 'sub_grade:D1', 'sub_grade:D2', 'sub_grade:D3',
#        'sub_grade:D4', 'sub_grade:D5', 'sub_grade:E1', 'sub_grade:E2',
#        'sub_grade:E3', 'sub_grade:E4', 'sub_grade:E5', 'sub_grade:F1',
#        'sub_grade:F2', 'sub_grade:F3', 'sub_grade:F4', 'sub_grade:F5',
#        'sub_grade:G1', 'sub_grade:G2', 'sub_grade:G3', 'sub_grade:G4',
#        'sub_grade:G5', 'home_ownership:ANY', 'home_ownership:MORTGAGE',
#        'home_ownership:NONE', 'home_ownership:OTHER',
#        'home_ownership:OWN', 'home_ownership:RENT',
#        'verification_status:Not Verified',
#        'verification_status:Source Verified',
#        'verification_status:Verified', 'loan_status:Charged Off',
#        'loan_status:Current', 'loan_status:Default',
#        'loan_status:Does not meet the credit policy. Status:Charged Off',
#        'loan_status:Does not meet the credit policy. Status:Fully Paid',
#        'loan_status:Fully Paid', 'loan_status:In Grace Period',
#        'loan_status:Late (16-30 days)', 'loan_status:Late (31-120 days)',
#        'purpose:car', 'purpose:credit_card', 'purpose:debt_consolidation',
#        'purpose:educational', 'purpose:home_improvement', 'purpose:house',
#        'purpose:major_purchase', 'purpose:medical', 'purpose:moving',
#        'purpose:other', 'purpose:renewable_energy',
#        'purpose:small_business', 'purpose:vacation', 'purpose:wedding',
#        'addr_state:AK', 'addr_state:AL', 'addr_state:AR', 'addr_state:AZ',
#        'addr_state:CA', 'addr_state:CO', 'addr_state:CT', 'addr_state:DC',
#        'addr_state:DE', 'addr_state:FL', 'addr_state:GA', 'addr_state:HI',
#        'addr_state:IA', 'addr_state:ID', 'addr_state:IL', 'addr_state:IN',
#        'addr_state:KS', 'addr_state:KY', 'addr_state:LA', 'addr_state:MA',
#        'addr_state:MD', 'addr_state:ME', 'addr_state:MI', 'addr_state:MN',
#        'addr_state:MO', 'addr_state:MS', 'addr_state:MT', 'addr_state:NC',
#        'addr_state:NE', 'addr_state:NH', 'addr_state:NJ', 'addr_state:NM',
#        'addr_state:NV', 'addr_state:NY', 'addr_state:OH', 'addr_state:OK',
#        'addr_state:OR', 'addr_state:PA', 'addr_state:RI', 'addr_state:SC',
#        'addr_state:SD', 'addr_state:TN', 'addr_state:TX', 'addr_state:UT',
#        'addr_state:VA', 'addr_state:VT', 'addr_state:WA', 'addr_state:WI',
#        'addr_state:WV', 'addr_state:WY', 'initial_list_status:f',
#        'initial_list_status:w', 'home_owndership: rent_other_none_any',
#        'addr_state:ND', 'addr_state:ND_NE_IA_NV_FL_HI_AL',
#        'addr_state:NM_VA', 'addr_state:OK_TN_MO_LA_MD_NC',
#        'addr_state:UT_KY_AZ_NJ', 'addr_state:AR_MI_PA_OH_MN',
#        'addr_state:RI_MA_DE_SD_IN', 'addr_state:GA_WA_OR',
#        'addr_state:WI_MT', 'addr_state:IL_CT',
#        'addr_state:KS_SC_CO_VT_AK_MS', 'addr_state:WV_NH_WY_DC_ME_ID',
#        'purpose:educ__sm_b__wedd__ren_en__mov__house',
#        'purpose:oth__med__vacation',
#        'purpose:major_purch__car__home_impr', 'term:36', 'term:60',
#        'emp_length:0', 'emp_length:1', 'emp_length:2-4', 'emp_length:5-6',
#        'emp_length:7-9', 'emp_length:10', 'mths_since_issue_d_factor',
#        'mths_since_issue_d:<38', 'mths_since_issue_d:38-39',
#        'mths_since_issue_d:40-41', 'mths_since_issue_d:42-48',
#        'mths_since_issue_d:49-52', 'mths_since_issue_d:53-64',
#        'mths_since_issue_d:65-84', 'mths_since_issue_d:>84',
#        'int_rate_factor', 'int_rate:<9.548', 'int_rate:9.548-12.025',
#        'int_rate:12.025-15.74', 'int_rate:15.74-20.281',
#        'int_rate:>20.281', 'funded_amnt_factor',
#        'mths_since_earliest_cr_line_factor',
#        'mths_since_earliest_cr_line:<140',
#        'mths_since_earliest_cr_line:141-164',
#        'mths_since_earliest_cr_line:165-247',
#        'mths_since_earliest_cr_line:248-270',
#        'mths_since_earliest_cr_line:271-352',
#        'mths_since_earliest_cr_line:>352', 'delinq_2yrs:0',
#        'delinq_2yrs:1-3', 'delinq_2yrs:>=4', 'inq_last_6mths:0',
#        'inq_last_6mths:1-2', 'inq_last_6mths:3-6', 'inq_last_6mths:>6',
#        'open_acc:0', 'open_acc:1-3', 'open_acc:4-12', 'open_acc:13-17',
#        'open_acc:18-22', 'open_acc:23-25', 'open_acc:26-30',
#        'open_acc:>=31', 'pub_rec:0-2', 'pub_rec:3-4', 'pub_rec:>=5',
#        'total_acc_factor', 'total_acc:<=27', 'total_acc:28-51',
#        'total_acc:>=52', 'acc_now_delinq:0', 'acc_now_delinq:>=1',
#        'total_rev_hi_lim_factor', 'total_rev_hi_lim:<=5K',
#        'total_rev_hi_lim:5K-10K', 'total_rev_hi_lim:10K-20K',
#        'total_rev_hi_lim:20K-30K', 'total_rev_hi_lim:30K-40K',
#        'total_rev_hi_lim:40K-55K', 'total_rev_hi_lim:55K-95K',
#        'total_rev_hi_lim:>95K', 'installment_factor', 'annual_inc_factor',
#        'annual_inc:<20K', 'annual_inc:20K-30K', 'annual_inc:30K-40K',
#        'annual_inc:40K-50K', 'annual_inc:50K-60K', 'annual_inc:60K-70K',
#        'annual_inc:70K-80K', 'annual_inc:80K-90K', 'annual_inc:90K-100K',
#        'annual_inc:100K-120K', 'annual_inc:120K-140K', 'annual_inc:>140K',
#        'mths_since_last_delinq:Missing', 'mths_since_last_delinq:0-3',
#        'mths_since_last_delinq:4-30', 'mths_since_last_delinq:31-56',
#        'mths_since_last_delinq:>=57', 'dti_factor', 'dti:<=1.4',
#        'dti:1.4-3.5', 'dti:3.5-7.7', 'dti:7.7-10.5', 'dti:10.5-16.1',
#        'dti:16.1-20.3', 'dti:20.3-21.7', 'dti:21.7-22.4', 'dti:22.4-35',
#        'dti:>35', 'mths_since_last_record:Missing',
#        'mths_since_last_record:0-2', 'mths_since_last_record:3-20',
#        'mths_since_last_record:21-31', 'mths_since_last_record:32-80',
#        'mths_since_last_record:81-86', 'mths_since_last_record:>=86',
#        'home_ownership: rent_other_none_any'], dtype=object)

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership: rent_other_none_any',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership: rent_other_none_any',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 104567     True    False    False    False    False    False
# 19977     False    False    False    False     True    False
# 208099     True    False    False    False    False    False
# 206328    False    False     True    False    False    False
# 377868     True    False    False    False    False    False
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 104567               False                     True                 0
# 19977                False                     True                 0
# 208099               False                    False                 0
# 206328               False                     True                 0
# 377868               False                     True                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 104567          False  ...                               0
# 19977           False  ...                               1
# 208099          False  ...                               0
# 206328          False  ...                               1
# 377868          False  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 104567                            0                             1
# 19977                             0                             0
# 208099                            0                             0
# 206328                            0                             0
# 377868                            0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 104567                            0                               1
# 19977                             0                               1
# 208099                            1                               1
# 206328                            0                               1
# 377868                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 104567                            0                             0
# 19977                             0                             0
# 208099                            0                             0
# 206328                            0                             0
# 377868                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 104567                             0                             0
# 19977                              0                             0
# 208099                             0                             0
# 206328                             0                             0
# 377868                             0                             0
#
#         mths_since_last_record:>=86
# 104567                            0
# 19977                             0
# 208099                            0
# 206328                            0
# 377868                            0
#
# [5 rows x 104 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
loan_data_inputs_train.head(10)
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 104567      104567   6616752    8198895       9600         9600
# 19977        19977    666996     852743      18000        18000
# 208099      208099   1416681    1666699      10000        10000
# 206328      206328   1435772    1687345      30000        30000
# 377868      377868  16221339   18323829      22000        22000
# 228518      228518   1107452    1343695       8000         8000
# 7105          7105    886326    1102131      28200        28200
# 453569      453569  10865025   12747168      12000        12000
# 94343        94343   7056506    8718640      11975        11975
# 271847      271847  16511483   18644007       7000         7000
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 104567       9550.00000   36 months      8.90       304.84     A  ...
# 19977       18000.00000   60 months     16.77       445.13     E  ...
# 208099      10000.00000   36 months      8.90       317.54     A  ...
# 206328      30000.00000   36 months     17.27      1073.62     C  ...
# 377868      22000.00000   36 months      7.69       686.26     A  ...
# 228518       7750.00000   36 months     10.65       260.59     B  ...
# 7105        28040.80268   60 months     18.64       725.95     E  ...
# 453569      11950.00000   60 months     13.53       276.31     B  ...
# 94343       11975.00000   36 months      8.90       380.25     A  ...
# 271847       7000.00000   36 months     13.98       239.18     C  ...
#
#        dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 104567           0       0                              1
# 19977            1       0                              1
# 208099           0       0                              1
# 206328           0       0                              1
# 377868           0       0                              1
# 228518           0       0                              1
# 7105             0       0                              0
# 453569           0       0                              1
# 94343            0       0                              1
# 271847           0       0                              1
#
#        mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 104567                          0                            0
# 19977                           0                            0
# 208099                          0                            0
# 206328                          0                            0
# 377868                          0                            0
# 228518                          0                            0
# 7105                            0                            0
# 453569                          0                            0
# 94343                           0                            0
# 271847                          0                            0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 104567                            0                            0
# 19977                             0                            0
# 208099                            0                            0
# 206328                            0                            0
# 377868                            0                            0
# 228518                            0                            0
# 7105                              0                            0
# 453569                            0                            0
# 94343                             0                            0
# 271847                            0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>=86  \
# 104567                            0                           0
# 19977                             0                           0
# 208099                            0                           0
# 206328                            0                           0
# 377868                            0                           0
# 228518                            0                           0
# 7105                              0                           1
# 453569                            0                           0
# 94343                             0                           0
# 271847                            0                           0
#
#        home_ownership: rent_other_none_any
# 104567                                   0
# 19977                                    0
# 208099                                   1
# 206328                                   0
# 377868                                   0
# 228518                                   0
# 7105                                     0
# 453569                                   0
# 94343                                    0
# 271847                                   1
#
# [10 rows x 325 columns]

# %%
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col = 0)
loan_data_targets_train.head(10)
print(loan_data_inputs_train.shape)
# Out:
# (373028, 325)

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# c:\Users\wlgan\credit_risk_modelling\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-0.55246769])

# %%
reg.coef_
# Out:
# array([[ 0.92503627,  0.76619686,  0.59171637,  0.41517671,  0.27714996,
#          0.16704195,  0.08707029,  0.10980406,  0.07991579,  0.08569882,
#          0.08728784,  0.0976751 ,  0.11290893,  0.17667741,  0.1272831 ,
#          0.23625272,  0.26041009,  0.28474658,  0.29837062,  0.37834584,
#          0.47907857,  0.0833828 , -0.00984969,  0.28553767,  0.16927973,
#          0.17277158,  0.21491407,  0.05208441,  0.07891128,  0.11260558,
#          0.12654164,  0.10291304,  0.07101353,  0.12817223,  1.14296273,
#          0.94879333,  0.84981027,  0.63809518,  0.48784315,  0.2402791 ,
#         -0.00805514,  1.06753545,  0.65707223,  0.38966265,  0.17335264,
#          0.08484875,  0.06029539,  0.09370026,  0.13651505,  0.15311579,
#         -0.04236235, -0.05140468,  0.25639009,  0.11091596, -0.09122279,
#          0.0296164 , -0.04616248, -0.0676606 , -0.0830067 , -0.09426678,
#         -0.06292652, -0.16898862, -0.01137322,  0.08385808, -0.02792457,
#         -0.0152767 ,  0.11278464,  0.03473767,  0.01096766,  0.00626913,
#          0.02184222,  0.04881438,  0.06045517,  0.19109881, -0.1241095 ,
#         -0.06915246,  0.02887091,  0.08025831,  0.18833361,  0.25998061,
#          0.33523693,  0.35230398,  0.39647913,  0.50692306,  0.44490049,
#          0.09191408,  0.18256631,  0.18371821,  0.12945535,  0.05472178,
#         -0.0335223 , -0.02533483, -0.10691447, -0.13096567,  0.13287523,
#          0.16986431,  0.20510139,  0.16802354,  0.11048965,  0.17149079,
#          0.16198594,  0.30624503, -0.07172356,  0.01926577]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -0.552468
# 1                                grade:A      0.925036
# 2                                grade:B      0.766197
# 3                                grade:C      0.591716
# 4                                grade:D      0.415177
# 5                                grade:E      0.277150
# 6                                grade:F      0.167042
# 7                     home_ownership:OWN      0.087070
# 8                home_ownership:MORTGAGE      0.109804
# 9                       addr_state:NM_VA      0.079916
# 10                         addr_state:NY      0.085699
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.087288
# 12                         addr_state:CA      0.097675
# 13                addr_state:UT_KY_AZ_NJ      0.112909
# 14             addr_state:AR_MI_PA_OH_MN      0.176677
# 15             addr_state:RI_MA_DE_SD_IN      0.127283
# 16                   addr_state:GA_WA_OR      0.236253
# 17                      addr_state:WI_MT      0.260410
# 18                         addr_state:TX      0.284747
# 19                      addr_state:IL_CT      0.298371
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.378346
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.479079
# 22      verification_status:Not Verified      0.083383
# 23   verification_status:Source Verified     -0.009850
# 24                   purpose:credit_card      0.285538
# 25            purpose:debt_consolidation      0.169280
# 26            purpose:oth__med__vacation      0.172772
# 27   purpose:major_purch__car__home_impr      0.214914
# 28                 initial_list_status:w      0.052084
# 29                               term:36      0.078911
# 30                          emp_length:1      0.112606
# 31                        emp_length:2-4      0.126542
# 32                        emp_length:5-6      0.102913
# 33                        emp_length:7-9      0.071014
# 34                         emp_length:10      0.128172
# 35                mths_since_issue_d:<38      1.142963
# 36              mths_since_issue_d:38-39      0.948793
# 37              mths_since_issue_d:40-41      0.849810
# 38              mths_since_issue_d:42-48      0.638095
# 39              mths_since_issue_d:49-52      0.487843
# 40              mths_since_issue_d:53-64      0.240279
# 41              mths_since_issue_d:65-84     -0.008055
# 42                       int_rate:<9.548      1.067535
# 43                 int_rate:9.548-12.025      0.657072
# 44                 int_rate:12.025-15.74      0.389663
# 45                 int_rate:15.74-20.281      0.173353
# 46   mths_since_earliest_cr_line:141-164      0.084849
# 47   mths_since_earliest_cr_line:165-247      0.060295
# 48   mths_since_earliest_cr_line:248-270      0.093700
# 49   mths_since_earliest_cr_line:271-352      0.136515
# 50      mths_since_earliest_cr_line:>352      0.153116
# 51                         delinq_2yrs:0     -0.042362
# 52                       delinq_2yrs:1-3     -0.051405
# 53                      inq_last_6mths:0      0.256390
# 54                    inq_last_6mths:1-2      0.110916
# 55                    inq_last_6mths:3-6     -0.091223
# 56                          open_acc:1-3      0.029616
# 57                         open_acc:4-12     -0.046162
# 58                        open_acc:13-17     -0.067661
# 59                        open_acc:18-22     -0.083007
# 60                        open_acc:23-25     -0.094267
# 61                        open_acc:26-30     -0.062927
# 62                         open_acc:>=31     -0.168989
# 63                           pub_rec:3-4     -0.011373
# 64                           pub_rec:>=5      0.083858
# 65                       total_acc:28-51     -0.027925
# 66                        total_acc:>=52     -0.015277
# 67                    acc_now_delinq:>=1      0.112785
# 68               total_rev_hi_lim:5K-10K      0.034738
# 69              total_rev_hi_lim:10K-20K      0.010968
# 70              total_rev_hi_lim:20K-30K      0.006269
# 71              total_rev_hi_lim:30K-40K      0.021842
# 72              total_rev_hi_lim:40K-55K      0.048814
# 73              total_rev_hi_lim:55K-95K      0.060455
# 74                 total_rev_hi_lim:>95K      0.191099
# 75                    annual_inc:20K-30K     -0.124109
# 76                    annual_inc:30K-40K     -0.069152
# 77                    annual_inc:40K-50K      0.028871
# 78                    annual_inc:50K-60K      0.080258
# 79                    annual_inc:60K-70K      0.188334
# 80                    annual_inc:70K-80K      0.259981
# 81                    annual_inc:80K-90K      0.335237
# 82                   annual_inc:90K-100K      0.352304
# 83                  annual_inc:100K-120K      0.396479
# 84                  annual_inc:120K-140K      0.506923
# 85                      annual_inc:>140K      0.444900
# 86                             dti:<=1.4      0.091914
# 87                           dti:1.4-3.5      0.182566
# 88                           dti:3.5-7.7      0.183718
# 89                          dti:7.7-10.5      0.129455
# 90                         dti:10.5-16.1      0.054722
# 91                         dti:16.1-20.3     -0.033522
# 92                         dti:20.3-21.7     -0.025335
# 93                         dti:21.7-22.4     -0.106914
# 94                           dti:22.4-35     -0.130966
# 95        mths_since_last_delinq:Missing      0.132875
# 96           mths_since_last_delinq:4-30      0.169864
# 97          mths_since_last_delinq:31-56      0.205101
# 98           mths_since_last_delinq:>=57      0.168024
# 99        mths_since_last_record:Missing      0.110490
# 100          mths_since_last_record:3-20      0.171491
# 101         mths_since_last_record:21-31      0.161986
# 102         mths_since_last_record:32-80      0.306245
# 103         mths_since_last_record:81-86     -0.071724
# 104          mths_since_last_record:>=86      0.019266

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        print(type(F_ij))
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# c:\Users\wlgan\credit_risk_modelling\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# <class 'numpy.ndarray'>

# %%
p_values = reg.p_values
p_values
# Out:
# [np.float64(1.1063745805888544e-23),
#  np.float64(2.9704780098104263e-36),
#  np.float64(1.1911592940115446e-25),
#  np.float64(1.0368647703346059e-14),
#  np.float64(7.37914149569071e-09),
#  np.float64(0.0008607205599922487),
#  np.float64(1.5329427009526075e-05),
#  np.float64(5.330760542887109e-18),
#  np.float64(0.012588517038916653),
#  np.float64(0.0003818587673088863),
#  np.float64(0.00015240880212858332),
#  np.float64(3.7357357171882594e-06),
#  np.float64(5.269862037757459e-06),
#  np.float64(3.4166820337541596e-15),
#  np.float64(2.0007375381706256e-05),
#  np.float64(8.974058267256284e-19),
#  np.float64(3.5584540831441575e-08),
#  np.float64(8.176462810701018e-28),
#  np.float64(1.452573165097777e-24),
#  np.float64(2.403659183780658e-34),
#  np.float64(1.9079625526440874e-20),
#  np.float64(1.3505640039220391e-08),
#  np.float64(0.4648938222875967),
#  np.float64(1.8408953996474508e-23),
#  np.float64(1.2270056865669496e-10),
#  np.float64(3.317371223514206e-08),
#  np.float64(7.98113579629584e-12),
#  np.float64(6.711108402574524e-05),
#  np.float64(2.6944585104068537e-08),
#  np.float64(1.5162434152437538e-05),
#  np.float64(1.8811276254584583e-11),
#  np.float64(1.5556024790796103e-06),
#  np.float64(0.0006367028409145051),
#  np.float64(3.4049118985479512e-12),
#  np.float64(1.7479987131715285e-196),
#  np.float64(9.366532872046418e-169),
#  np.float64(1.98766413820974e-142),
#  np.float64(3.222808506947971e-103),
#  np.float64(9.837354689979522e-54),
#  np.float64(6.044199485840484e-16),
#  np.float64(0.7806333366168493),
#  np.float64(1.7084112121643337e-42),
#  np.float64(1.5720066160557786e-48),
#  np.float64(5.528338843770694e-26),
#  np.float64(2.7684332604135355e-09),
#  np.float64(0.0006799036790630753),
#  np.float64(0.0029809682344028514),
#  np.float64(0.0004152226068125775),
#  np.float64(9.94194498700627e-09),
#  np.float64(1.5026716431382228e-08),
#  np.float64(0.466415803020078),
#  np.float64(0.3491899484411839),
#  np.float64(0.035672625007899396),
#  np.float64(0.3629229109954515),
#  np.float64(0.45607434886343723),
#  np.float64(0.8629999519026024),
#  np.float64(0.7834520000567418),
#  np.float64(0.6876690325863406),
#  np.float64(0.6237563088573803),
#  np.float64(0.5874442588182012),
#  np.float64(0.7248057042552585),
#  np.float64(0.3767413895707432),
#  np.float64(0.8989887286580563),
#  np.float64(0.6456407396557284),
#  np.float64(0.04941803342943313),
#  np.float64(0.6977156613996952),
#  np.float64(0.2711898833859264),
#  np.float64(0.15696360584913707),
#  np.float64(0.6451592189220529),
#  np.float64(0.8107981198932876),
#  np.float64(0.4582020826973646),
#  np.float64(0.12900613941008215),
#  np.float64(0.09269234217770188),
#  np.float64(0.0006443369158522314),
#  np.float64(0.004416515369495277),
#  np.float64(0.10058651293369775),
#  np.float64(0.4938224818718432),
#  np.float64(0.06037959680017692),
#  np.float64(1.6993185819773497e-05),
#  np.float64(5.848626530249283e-09),
#  np.float64(5.641557568421329e-13),
#  np.float64(2.2396270969602485e-13),
#  np.float64(8.654701891089885e-17),
#  np.float64(4.532448259291548e-21),
#  np.float64(7.589121278570592e-19),
#  np.float64(0.31631687044673107),
#  np.float64(0.019236766157672048),
#  np.float64(0.007589483739543146),
#  np.float64(0.058082174378810754),
#  np.float64(0.4101156490229023),
#  np.float64(0.6137051322061788),
#  np.float64(0.7125112529051401),
#  np.float64(0.13897853593478607),
#  np.float64(0.0461955599744838),
#  np.float64(0.019599036215975963),
#  np.float64(0.0012971914142084384),
#  np.float64(0.00041355931392456617),
#  np.float64(0.004566119195996002),
#  np.float64(0.15792566098931426),
#  np.float64(0.1515727247077628),
#  np.float64(0.14433844114435718),
#  np.float64(0.00020597501136210785),
#  np.float64(0.4165764681739531),
#  np.float64(0.8086904801575033)]

# %%
p_values = np.append(np.nan, np.array(p_values))

# %%
p_values
# Out:
# array([            nan, 1.10637458e-023, 2.97047801e-036, 1.19115929e-025,
#        1.03686477e-014, 7.37914150e-009, 8.60720560e-004, 1.53294270e-005,
#        5.33076054e-018, 1.25885170e-002, 3.81858767e-004, 1.52408802e-004,
#        3.73573572e-006, 5.26986204e-006, 3.41668203e-015, 2.00073754e-005,
#        8.97405827e-019, 3.55845408e-008, 8.17646281e-028, 1.45257317e-024,
#        2.40365918e-034, 1.90796255e-020, 1.35056400e-008, 4.64893822e-001,
#        1.84089540e-023, 1.22700569e-010, 3.31737122e-008, 7.98113580e-012,
#        6.71110840e-005, 2.69445851e-008, 1.51624342e-005, 1.88112763e-011,
#        1.55560248e-006, 6.36702841e-004, 3.40491190e-012, 1.74799871e-196,
#        9.36653287e-169, 1.98766414e-142, 3.22280851e-103, 9.83735469e-054,
#        6.04419949e-016, 7.80633337e-001, 1.70841121e-042, 1.57200662e-048,
#        5.52833884e-026, 2.76843326e-009, 6.79903679e-004, 2.98096823e-003,
#        4.15222607e-004, 9.94194499e-009, 1.50267164e-008, 4.66415803e-001,
#        3.49189948e-001, 3.56726250e-002, 3.62922911e-001, 4.56074349e-001,
#        8.62999952e-001, 7.83452000e-001, 6.87669033e-001, 6.23756309e-001,
#        5.87444259e-001, 7.24805704e-001, 3.76741390e-001, 8.98988729e-001,
#        6.45640740e-001, 4.94180334e-002, 6.97715661e-001, 2.71189883e-001,
#        1.56963606e-001, 6.45159219e-001, 8.10798120e-001, 4.58202083e-001,
#        1.29006139e-001, 9.26923422e-002, 6.44336916e-004, 4.41651537e-003,
#        1.00586513e-001, 4.93822482e-001, 6.03795968e-002, 1.69931858e-005,
#        5.84862653e-009, 5.64155757e-013, 2.23962710e-013, 8.65470189e-017,
#        4.53244826e-021, 7.58912128e-019, 3.16316870e-001, 1.92367662e-002,
#        7.58948374e-003, 5.80821744e-002, 4.10115649e-001, 6.13705132e-001,
#        7.12511253e-001, 1.38978536e-001, 4.61955600e-002, 1.95990362e-002,
#        1.29719141e-003, 4.13559314e-004, 4.56611920e-003, 1.57925661e-001,
#        1.51572725e-001, 1.44338441e-001, 2.05975011e-004, 4.16576468e-001,
#        8.08690480e-001])

# %%
summary_table['p_values'] = p_values

# %%
summary_table
# Out:
#                             Feature name  Coefficients       p_values
# 0                              Intercept     -0.552468            NaN
# 1                                grade:A      0.925036   1.106375e-23
# 2                                grade:B      0.766197   2.970478e-36
# 3                                grade:C      0.591716   1.191159e-25
# 4                                grade:D      0.415177   1.036865e-14
# 5                                grade:E      0.277150   7.379141e-09
# 6                                grade:F      0.167042   8.607206e-04
# 7                     home_ownership:OWN      0.087070   1.532943e-05
# 8                home_ownership:MORTGAGE      0.109804   5.330761e-18
# 9                       addr_state:NM_VA      0.079916   1.258852e-02
# 10                         addr_state:NY      0.085699   3.818588e-04
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.087288   1.524088e-04
# 12                         addr_state:CA      0.097675   3.735736e-06
# 13                addr_state:UT_KY_AZ_NJ      0.112909   5.269862e-06
# 14             addr_state:AR_MI_PA_OH_MN      0.176677   3.416682e-15
# 15             addr_state:RI_MA_DE_SD_IN      0.127283   2.000738e-05
# 16                   addr_state:GA_WA_OR      0.236253   8.974058e-19
# 17                      addr_state:WI_MT      0.260410   3.558454e-08
# 18                         addr_state:TX      0.284747   8.176463e-28
# 19                      addr_state:IL_CT      0.298371   1.452573e-24
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.378346   2.403659e-34
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.479079   1.907963e-20
# 22      verification_status:Not Verified      0.083383   1.350564e-08
# 23   verification_status:Source Verified     -0.009850   4.648938e-01
# 24                   purpose:credit_card      0.285538   1.840895e-23
# 25            purpose:debt_consolidation      0.169280   1.227006e-10
# 26            purpose:oth__med__vacation      0.172772   3.317371e-08
# 27   purpose:major_purch__car__home_impr      0.214914   7.981136e-12
# 28                 initial_list_status:w      0.052084   6.711108e-05
# 29                               term:36      0.078911   2.694459e-08
# 30                          emp_length:1      0.112606   1.516243e-05
# 31                        emp_length:2-4      0.126542   1.881128e-11
# 32                        emp_length:5-6      0.102913   1.555602e-06
# 33                        emp_length:7-9      0.071014   6.367028e-04
# 34                         emp_length:10      0.128172   3.404912e-12
# 35                mths_since_issue_d:<38      1.142963  1.747999e-196
# 36              mths_since_issue_d:38-39      0.948793  9.366533e-169
# 37              mths_since_issue_d:40-41      0.849810  1.987664e-142
# 38              mths_since_issue_d:42-48      0.638095  3.222809e-103
# 39              mths_since_issue_d:49-52      0.487843   9.837355e-54
# 40              mths_since_issue_d:53-64      0.240279   6.044199e-16
# 41              mths_since_issue_d:65-84     -0.008055   7.806333e-01
# 42                       int_rate:<9.548      1.067535   1.708411e-42
# 43                 int_rate:9.548-12.025      0.657072   1.572007e-48
# 44                 int_rate:12.025-15.74      0.389663   5.528339e-26
# 45                 int_rate:15.74-20.281      0.173353   2.768433e-09
# 46   mths_since_earliest_cr_line:141-164      0.084849   6.799037e-04
# 47   mths_since_earliest_cr_line:165-247      0.060295   2.980968e-03
# 48   mths_since_earliest_cr_line:248-270      0.093700   4.152226e-04
# 49   mths_since_earliest_cr_line:271-352      0.136515   9.941945e-09
# 50      mths_since_earliest_cr_line:>352      0.153116   1.502672e-08
# 51                         delinq_2yrs:0     -0.042362   4.664158e-01
# 52                       delinq_2yrs:1-3     -0.051405   3.491899e-01
# 53                      inq_last_6mths:0      0.256390   3.567263e-02
# 54                    inq_last_6mths:1-2      0.110916   3.629229e-01
# 55                    inq_last_6mths:3-6     -0.091223   4.560743e-01
# 56                          open_acc:1-3      0.029616   8.630000e-01
# 57                         open_acc:4-12     -0.046162   7.834520e-01
# 58                        open_acc:13-17     -0.067661   6.876690e-01
# 59                        open_acc:18-22     -0.083007   6.237563e-01
# 60                        open_acc:23-25     -0.094267   5.874443e-01
# 61                        open_acc:26-30     -0.062927   7.248057e-01
# 62                         open_acc:>=31     -0.168989   3.767414e-01
# 63                           pub_rec:3-4     -0.011373   8.989887e-01
# 64                           pub_rec:>=5      0.083858   6.456407e-01
# 65                       total_acc:28-51     -0.027925   4.941803e-02
# 66                        total_acc:>=52     -0.015277   6.977157e-01
# 67                    acc_now_delinq:>=1      0.112785   2.711899e-01
# 68               total_rev_hi_lim:5K-10K      0.034738   1.569636e-01
# 69              total_rev_hi_lim:10K-20K      0.010968   6.451592e-01
# 70              total_rev_hi_lim:20K-30K      0.006269   8.107981e-01
# 71              total_rev_hi_lim:30K-40K      0.021842   4.582021e-01
# 72              total_rev_hi_lim:40K-55K      0.048814   1.290061e-01
# 73              total_rev_hi_lim:55K-95K      0.060455   9.269234e-02
# 74                 total_rev_hi_lim:>95K      0.191099   6.443369e-04
# 75                    annual_inc:20K-30K     -0.124109   4.416515e-03
# 76                    annual_inc:30K-40K     -0.069152   1.005865e-01
# 77                    annual_inc:40K-50K      0.028871   4.938225e-01
# 78                    annual_inc:50K-60K      0.080258   6.037960e-02
# 79                    annual_inc:60K-70K      0.188334   1.699319e-05
# 80                    annual_inc:70K-80K      0.259981   5.848627e-09
# 81                    annual_inc:80K-90K      0.335237   5.641558e-13
# 82                   annual_inc:90K-100K      0.352304   2.239627e-13
# 83                  annual_inc:100K-120K      0.396479   8.654702e-17
# 84                  annual_inc:120K-140K      0.506923   4.532448e-21
# 85                      annual_inc:>140K      0.444900   7.589121e-19
# 86                             dti:<=1.4      0.091914   3.163169e-01
# 87                           dti:1.4-3.5      0.182566   1.923677e-02
# 88                           dti:3.5-7.7      0.183718   7.589484e-03
# 89                          dti:7.7-10.5      0.129455   5.808217e-02
# 90                         dti:10.5-16.1      0.054722   4.101156e-01
# 91                         dti:16.1-20.3     -0.033522   6.137051e-01
# 92                         dti:20.3-21.7     -0.025335   7.125113e-01
# 93                         dti:21.7-22.4     -0.106914   1.389785e-01
# 94                           dti:22.4-35     -0.130966   4.619556e-02
# 95        mths_since_last_delinq:Missing      0.132875   1.959904e-02
# 96           mths_since_last_delinq:4-30      0.169864   1.297191e-03
# 97          mths_since_last_delinq:31-56      0.205101   4.135593e-04
# 98           mths_since_last_delinq:>=57      0.168024   4.566119e-03
# 99        mths_since_last_record:Missing      0.110490   1.579257e-01
# 100          mths_since_last_record:3-20      0.171491   1.515727e-01
# 101         mths_since_last_record:21-31      0.161986   1.443384e-01
# 102         mths_since_last_record:32-80      0.306245   2.059750e-04
# 103         mths_since_last_record:81-86     -0.071724   4.165765e-01
# 104          mths_since_last_record:>=86      0.019266   8.086905e-01

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership: rent_other_none_any',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership: rent_other_none_any',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head(10)
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 104567     True    False    False    False    False    False
# 19977     False    False    False    False     True    False
# 208099     True    False    False    False    False    False
# 206328    False    False     True    False    False    False
# 377868     True    False    False    False    False    False
# 228518    False     True    False    False    False    False
# 7105      False    False    False    False     True    False
# 453569    False     True    False    False    False    False
# 94343      True    False    False    False    False    False
# 271847    False    False     True    False    False    False
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 104567               False                     True                 0
# 19977                False                     True                 0
# 208099               False                    False                 0
# 206328               False                     True                 0
# 377868               False                     True                 0
# 228518               False                     True                 0
# 7105                 False                     True                 0
# 453569               False                     True                 0
# 94343                False                     True                 0
# 271847               False                    False                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 104567          False  ...                               0
# 19977           False  ...                               1
# 208099          False  ...                               0
# 206328          False  ...                               1
# 377868          False  ...                               1
# 228518          False  ...                               1
# 7105            False  ...                               1
# 453569          False  ...                               0
# 94343           False  ...                               1
# 271847          False  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 104567                            0                             1
# 19977                             0                             0
# 208099                            0                             0
# 206328                            0                             0
# 377868                            0                             0
# 228518                            0                             0
# 7105                              0                             0
# 453569                            1                             0
# 94343                             0                             0
# 271847                            0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 104567                            0                               1
# 19977                             0                               1
# 208099                            1                               1
# 206328                            0                               1
# 377868                            0                               1
# 228518                            0                               1
# 7105                              0                               0
# 453569                            0                               1
# 94343                             0                               1
# 271847                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 104567                            0                             0
# 19977                             0                             0
# 208099                            0                             0
# 206328                            0                             0
# 377868                            0                             0
# 228518                            0                             0
# 7105                              0                             0
# 453569                            0                             0
# 94343                             0                             0
# 271847                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 104567                             0                             0
# 19977                              0                             0
# 208099                             0                             0
# 206328                             0                             0
# 377868                             0                             0
# 228518                             0                             0
# 7105                               0                             0
# 453569                             0                             0
# 94343                              0                             0
# 271847                             0                             0
#
#         mths_since_last_record:>=86
# 104567                            0
# 19977                             0
# 208099                            0
# 206328                            0
# 377868                            0
# 228518                            0
# 7105                              1
# 453569                            0
# 94343                             0
# 271847                            0
#
# [10 rows x 84 columns]

# %%
inputs_train.shape
# Out:
# (373028, 84)

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# c:\Users\wlgan\credit_risk_modelling\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# <class 'numpy.ndarray'>

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -0.691992
# 1                               grade:A      0.955482
# 2                               grade:B      0.812483
# 3                               grade:C      0.630172
# 4                               grade:D      0.448131
# 5                               grade:E      0.303362
# 6                               grade:F      0.161220
# 7                    home_ownership:OWN      0.085178
# 8               home_ownership:MORTGAGE      0.106054
# 9                      addr_state:NM_VA      0.069778
# 10                        addr_state:NY      0.059097
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.066848
# 12                        addr_state:CA      0.078078
# 13               addr_state:UT_KY_AZ_NJ      0.090089
# 14            addr_state:AR_MI_PA_OH_MN      0.152573
# 15            addr_state:RI_MA_DE_SD_IN      0.111332
# 16                  addr_state:GA_WA_OR      0.213539
# 17                     addr_state:WI_MT      0.244841
# 18                        addr_state:TX      0.259221
# 19                     addr_state:IL_CT      0.278390
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.327944
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.453391
# 22     verification_status:Not Verified      0.082742
# 23  verification_status:Source Verified     -0.008113
# 24                  purpose:credit_card      0.300300
# 25           purpose:debt_consolidation      0.186062
# 26           purpose:oth__med__vacation      0.209419
# 27  purpose:major_purch__car__home_impr      0.240777
# 28                initial_list_status:w      0.052884
# 29                              term:36      0.064805
# 30                         emp_length:1      0.109930
# 31                       emp_length:2-4      0.124517
# 32                       emp_length:5-6      0.100817
# 33                       emp_length:7-9      0.072331
# 34                        emp_length:10      0.129765
# 35               mths_since_issue_d:<38      1.110426
# 36             mths_since_issue_d:38-39      0.906774
# 37             mths_since_issue_d:40-41      0.812968
# 38             mths_since_issue_d:42-48      0.600237
# 39             mths_since_issue_d:49-52      0.451653
# 40             mths_since_issue_d:53-64      0.207453
# 41             mths_since_issue_d:65-84     -0.046302
# 42                      int_rate:<9.548      1.075411
# 43                int_rate:9.548-12.025      0.637195
# 44                int_rate:12.025-15.74      0.374125
# 45                int_rate:15.74-20.281      0.161804
# 46  mths_since_earliest_cr_line:141-164      0.076398
# 47  mths_since_earliest_cr_line:165-247      0.048364
# 48  mths_since_earliest_cr_line:248-270      0.078704
# 49  mths_since_earliest_cr_line:271-352      0.122480
# 50     mths_since_earliest_cr_line:>352      0.147718
# 51                     inq_last_6mths:0      0.262448
# 52                   inq_last_6mths:1-2      0.114374
# 53                   inq_last_6mths:3-6     -0.080537
# 54                   acc_now_delinq:>=1      0.107952
# 55                   annual_inc:20K-30K     -0.090376
# 56                   annual_inc:30K-40K     -0.034699
# 57                   annual_inc:40K-50K      0.058143
# 58                   annual_inc:50K-60K      0.108834
# 59                   annual_inc:60K-70K      0.209370
# 60                   annual_inc:70K-80K      0.288203
# 61                   annual_inc:80K-90K      0.371147
# 62                  annual_inc:90K-100K      0.390089
# 63                 annual_inc:100K-120K      0.435540
# 64                 annual_inc:120K-140K      0.532829
# 65                     annual_inc:>140K      0.451670
# 66                            dti:<=1.4      0.096560
# 67                          dti:1.4-3.5      0.224447
# 68                          dti:3.5-7.7      0.202309
# 69                         dti:7.7-10.5      0.141309
# 70                        dti:10.5-16.1      0.065440
# 71                        dti:16.1-20.3     -0.025731
# 72                        dti:20.3-21.7     -0.024549
# 73                        dti:21.7-22.4     -0.104321
# 74                          dti:22.4-35     -0.126125
# 75       mths_since_last_delinq:Missing      0.165671
# 76          mths_since_last_delinq:4-30      0.192505
# 77         mths_since_last_delinq:31-56      0.229004
# 78          mths_since_last_delinq:>=57      0.194332
# 79       mths_since_last_record:Missing      0.129398
# 80          mths_since_last_record:3-20      0.152377
# 81         mths_since_last_record:21-31      0.124882
# 82         mths_since_last_record:32-80      0.338708
# 83         mths_since_last_record:81-86     -0.069654
# 84          mths_since_last_record:>=86      0.038411

# %%
p_values = reg2.p_values
p_values = np.append(np.nan, np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -0.691992            NaN
# 1                               grade:A      0.955482   5.084932e-25
# 2                               grade:B      0.812483   6.520191e-41
# 3                               grade:C      0.630172   3.128271e-29
# 4                               grade:D      0.448131   3.503339e-17
# 5                               grade:E      0.303362   1.125757e-10
# 6                               grade:F      0.161220   9.972819e-04
# 7                    home_ownership:OWN      0.085178   2.214968e-05
# 8               home_ownership:MORTGAGE      0.106054   5.012981e-17
# 9                      addr_state:NM_VA      0.069778   2.986469e-02
# 10                        addr_state:NY      0.059097   1.420248e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.066848   3.751431e-03
# 12                        addr_state:CA      0.078078   2.221771e-04
# 13               addr_state:UT_KY_AZ_NJ      0.090089   2.811630e-04
# 14            addr_state:AR_MI_PA_OH_MN      0.152573   1.052609e-11
# 15            addr_state:RI_MA_DE_SD_IN      0.111332   1.954127e-04
# 16                  addr_state:GA_WA_OR      0.213539   1.263462e-15
# 17                     addr_state:WI_MT      0.244841   2.292700e-07
# 18                        addr_state:TX      0.259221   2.455142e-23
# 19                     addr_state:IL_CT      0.278390   1.434808e-21
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.327944   1.314932e-26
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.453391   1.560518e-18
# 22     verification_status:Not Verified      0.082742   1.378387e-08
# 23  verification_status:Source Verified     -0.008113   5.457336e-01
# 24                  purpose:credit_card      0.300300   2.613113e-26
# 25           purpose:debt_consolidation      0.186062   8.245935e-13
# 26           purpose:oth__med__vacation      0.209419   1.601544e-11
# 27  purpose:major_purch__car__home_impr      0.240777   1.175421e-14
# 28                initial_list_status:w      0.052884   5.086973e-05
# 29                              term:36      0.064805   3.655368e-06
# 30                         emp_length:1      0.109930   2.341270e-05
# 31                       emp_length:2-4      0.124517   3.682136e-11
# 32                       emp_length:5-6      0.100817   2.467066e-06
# 33                       emp_length:7-9      0.072331   5.009703e-04
# 34                        emp_length:10      0.129765   1.753496e-12
# 35               mths_since_issue_d:<38      1.110426  7.461350e-192
# 36             mths_since_issue_d:38-39      0.906774  3.993952e-161
# 37             mths_since_issue_d:40-41      0.812968  1.390315e-136
# 38             mths_since_issue_d:42-48      0.600237   2.369478e-96
# 39             mths_since_issue_d:49-52      0.451653   1.867779e-48
# 40             mths_since_issue_d:53-64      0.207453   8.303912e-13
# 41             mths_since_issue_d:65-84     -0.046302   1.108056e-01
# 42                      int_rate:<9.548      1.075411   1.046517e-42
# 43                int_rate:9.548-12.025      0.637195   2.921736e-46
# 44                int_rate:12.025-15.74      0.374125   2.305225e-24
# 45                int_rate:15.74-20.281      0.161804   2.410029e-08
# 46  mths_since_earliest_cr_line:141-164      0.076398   2.139198e-03
# 47  mths_since_earliest_cr_line:165-247      0.048364   1.575345e-02
# 48  mths_since_earliest_cr_line:248-270      0.078704   2.642131e-03
# 49  mths_since_earliest_cr_line:271-352      0.122480   1.535264e-07
# 50     mths_since_earliest_cr_line:>352      0.147718   2.599904e-08
# 51                     inq_last_6mths:0      0.262448   3.632285e-03
# 52                   inq_last_6mths:1-2      0.114374   2.044703e-01
# 53                   inq_last_6mths:3-6     -0.080537   3.747117e-01
# 54                   acc_now_delinq:>=1      0.107952   2.848830e-01
# 55                   annual_inc:20K-30K     -0.090376   3.255661e-02
# 56                   annual_inc:30K-40K     -0.034699   3.933276e-01
# 57                   annual_inc:40K-50K      0.058143   1.523222e-01
# 58                   annual_inc:50K-60K      0.108834   8.096358e-03
# 59                   annual_inc:60K-70K      0.209370   6.462987e-07
# 60                   annual_inc:70K-80K      0.288203   1.828382e-11
# 61                   annual_inc:80K-90K      0.371147   1.101976e-16
# 62                  annual_inc:90K-100K      0.390089   3.466695e-17
# 63                 annual_inc:100K-120K      0.435540   1.756879e-21
# 64                 annual_inc:120K-140K      0.532829   1.086578e-24
# 65                     annual_inc:>140K      0.451670   2.304754e-21
# 66                            dti:<=1.4      0.096560   2.603546e-01
# 67                          dti:1.4-3.5      0.224447   2.032242e-03
# 68                          dti:3.5-7.7      0.202309   1.388826e-03
# 69                         dti:7.7-10.5      0.141309   2.479039e-02
# 70                        dti:10.5-16.1      0.065440   2.838228e-01
# 71                        dti:16.1-20.3     -0.025731   6.738451e-01
# 72                        dti:20.3-21.7     -0.024549   7.000679e-01
# 73                        dti:21.7-22.4     -0.104321   1.222278e-01
# 74                          dti:22.4-35     -0.126125   3.705422e-02
# 75       mths_since_last_delinq:Missing      0.165671   1.182829e-03
# 76          mths_since_last_delinq:4-30      0.192505   1.970923e-04
# 77         mths_since_last_delinq:31-56      0.229004   1.233851e-05
# 78          mths_since_last_delinq:>=57      0.194332   2.952363e-04
# 79       mths_since_last_record:Missing      0.129398   8.134619e-02
# 80          mths_since_last_record:3-20      0.152377   1.838852e-01
# 81         mths_since_last_record:21-31      0.124882   2.400163e-01
# 82         mths_since_last_record:32-80      0.338708   1.633015e-05
# 83         mths_since_last_record:81-86     -0.069654   4.172706e-01
# 84          mths_since_last_record:>=86      0.038411   6.124613e-01

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
